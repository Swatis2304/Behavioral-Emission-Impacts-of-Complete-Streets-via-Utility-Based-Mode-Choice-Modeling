# %%
# 1. Extract
# download/read raw files

# 2. Transform
# filter NYC
# create tract IDs
# aggregate block-to-block flows to tract-to-tract
# join ACS mode share
# join tract geometry

# 3. Load
# save as parquet/csv/geopackage
